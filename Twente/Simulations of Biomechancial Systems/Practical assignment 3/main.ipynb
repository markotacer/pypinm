# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Practical 3

# %% [markdown]
# In this assignment we consider a system consisting of 2 rigid bodies, connected by a hinge joint. The parameter
# values are: \
# $$m = [30, 50] kg$$
# $$L = [0.9, 0.8] m$$
# $$Jc = [2, 3] kgm^2$$
# $$d = [0.5, 0.3] m$$
# These parameter values
# are such that the first segment may well represent the legs, and the second segment may well represent the
# trunk, arms and head, all viewed from the side. The system is connected to the world (floor) via a hinge joint,
# which represents the ankle. In this representation, the feet are considered part of the ground. The second hinge
# joint represents the hip (the model has no knees). There can act a net moment from the ground on the first
# segment M1 (representing the musculature spanning the ankle joint) and a net moment from the first segment
# on the second segment M2, representing the musculature round the hip joint. The first series of questions only
# concerns conceptual, paper-and-pen exercises. Grab sufficient paper, a cup of coffee, and a good pen

# %% [markdown]
# ### Locations of the gravitational force

# %% [markdown]
# #### $x_c$

# %% [markdown]
# Equation for $x_{c2}$:
# $$ L_{1}\cdot\cos{(\phi_{1}{(t)})} + d_{2}\cdot\cos{(\phi_{2}{(t)})} $$
#
# First derivative of $x_{c2}$ with respect to t:
# $$ - L_{1}\cdot\sin{(\phi_{1}{(t)})}\cdot\dot{\phi_{1}}{(t)} - d_{2}\cdot\sin{(\phi_{2}{(t)})}\cdot\dot{\phi_{2}}{(t)} $$
#
# Second derivative of $x_{c2}$ with respect to t:
# $$ - L_{1}\cdot\ddot{\phi_1}\cdot\sin{(\phi_{1}{(t)})} - L_{1}\cdot\cos{(\phi_{1}{(t)})}\cdot(\dot{\phi_{1}(t)})^{2} - d_{2}\cdot\sin{(\phi_{2}{(t)})}\cdot\ddot{\phi_{2}{(t)}} - d_{2}\cdot\cos{(\phi_{2}{(t)})}\cdot(\dot{\phi_{2}})^2 $$

# %% [markdown]
# #### $y_c$

# %% [markdown]
# Equation for $y_{c2}$:
# $$ L_{1}\cdot\sin{(\phi_{1}{(t)})} + d_{2}\cdot\sin{(\phi_{2}{(t)})} $$
#
# First derivative of $y_{c2}$ with respect to t:
# $$ L_{1}\cdot\cos{(\phi_{1}{(t)})}\cdot\dot{\phi_{1}}{(t)} + d_{2}\cdot\cos{(\phi_{2}{(t)})}\cdot\dot{\phi_{2}}{(t)} $$
#
# Second derivative of $y_{c2}$ with respect to t:
# $$ L_{1}\cdot\ddot{\phi_1}\cdot\cos{(\phi_{1}{(t)})} - L_{1}\cdot\sin{(\phi_{1}{(t)})}\cdot(\dot{\phi_{1}(t)})^{2}\
# \
#  + d_{2}\cdot\cos{(\phi_{2}{(t)})}\cdot\ddot{\phi_{2}{(t)}} - d_{2}\cdot\sin{(\phi_{2}{(t)})}\cdot(\dot{\phi_{2}})^2 $$

# %% [markdown]
# #### Translation equations
# $$\Sigma F_{x2} = m_2\cdot a_{x2} \rightarrow F_{2x} = m_2\cdot a_{x2} $$
# $$\Sigma F_{y2} = m_2\cdot a_{y2} \rightarrow F_{2y} - F_{g2} = m_2\cdot a_{y2} $$

# %% [markdown]
# #### Rotational equation
# $$\Sigma M_{/C} = J_2 \cdot \ddot{\phi_2}$$
# $$ - F_{2y} \cdot d_2 cos(\phi_2) + F_{2x} \cdot d_2 sin(\phi_2) + M_2/
# / = J_2 \cdot \ddot{\phi_2}$$
