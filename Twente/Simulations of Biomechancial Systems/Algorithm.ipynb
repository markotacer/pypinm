# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
import sympy as sp
from sympy import sin, cos, pi

# %% [markdown]
# $$F_1^x - F_2^x + F_{external}^x = m\cdot (\ddot{x_b} - d cos(\phi) (\dot{\phi})^2 - d sin(\phi) \ddot{\phi})$$
# $$F_1^y - F_2^y + F_{external}^y = m\cdot (\ddot{y_b} - d sin(\phi) (\dot{\phi})^2 - d cos(\phi) \ddot{\phi})$$
#
#
# $$M_1 - M_2 + M_{external} - d cos(\phi) F_1^y + d sin(\phi) F_1^x - (L-d) cos(\phi) F_2^y + (L-d) sin(\phi) F_2^x = J_{/C} \cdot \ddot{\phi}$$
