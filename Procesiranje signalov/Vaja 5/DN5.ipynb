# %%
import lvm_read
import matplotlib.pyplot as plt
import numpy as np

# %%
# Proces sig lv
# nastavili 100 samplou prej za zajema
#  zajame 25500 po udarcu
# meja za triger 2 Newton

# %%
i = 9
file = f'{i}signal.lvm'
loaded_data = lvm_read.read(file)
loaded_data.keys()
loaded_data['Segments']
# Out:
# 13

# %%
loaded_data[10]
# Out:
# {'Channels': 2,
#  'Samples': [51200, 51200, nan],
#  'Date': ['2023/04/05', '2023/04/05', ''],
#  'Time': ['15:21:05,4892699124997353126', '15:21:05,4892699124997353126', ''],
#  'Y_Unit_Label': ['Newtons', 'm/s^2', ''],
#  'X_Dimension': ['Time', 'Time', ''],
#  'X0': [48.27550781249998, 48.27550781249998, nan],
#  'Delta_X': [3.90625e-05, 3.90625e-05, nan],
#  'data': array([[ 4.8275508e+01,  4.8311000e-02,  1.4821000e-02],
#         [ 4.8275547e+01,  7.4883000e-02,  2.1229000e-02],
#         [ 4.8275586e+01,  3.9186000e-02,  1.9852000e-02],
#         ...,
#         [ 5.0275391e+01,  6.7636000e-02, -8.4576400e-01],
#         [ 5.0275430e+01,  6.8441000e-02, -8.4678200e-01],
#         [ 5.0275469e+01,  4.6701000e-02, -8.3791800e-01]]),
#  'Channel names': ['X_Value',
#   'Force (Trigger)',
#   'Acceleration (Trigger)',
#   'Comment']}

# %%
loaded_data['Segments']
# Out:
# 5

# %%
t = np.linspace(0, 1, 25600)
plt.figure()
plt.plot(t, kanal_1, label='Sila')
plt.xlim(0,0.1)
plt.grid()
plt.legend()

# %%
t = np.linspace(0, 1, 25600)
plt.figure()
plt.plot(t, kanal_2, label='Pospešek')
plt.xlim(0,0.1)
plt.grid()
plt.legend()

# %%
# Proces sig lv
# nastavili 100 samplou prej za zajema
#  zajame 25500 po udarcu
# meja za triger 2 Newton
